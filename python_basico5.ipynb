# %% [markdown]
# # Tarefa 03

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.

# %%
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
dados_rj = pd.DataFrame(r.json()['items'])
dados_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      21660           Estado  Rio de Janeiro        33  RJ
# 1       5923           Estado  Rio de Janeiro        33  RJ
# 2      13629           Estado  Rio de Janeiro        33  RJ
# 3       5630           Estado  Rio de Janeiro        33  RJ
# 4       5635           Estado  Rio de Janeiro        33  RJ
#
#                 num_pvl                                             status  \
# 0  00000.000000/2026-68                                 Arquivado a pedido
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None                                           Deferido
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.000245/2016-55  2016-03-11T03:00:00Z
# 1  17944.000234/2012-41  2012-04-16T03:00:00Z
# ...

# %% [markdown]
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?

# %%
print(dados_rj['status'].value_counts())
print(dados_rj['status'].value_counts(normalize = True)*100)
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64
# Encaminhado à PGFN com manifestação técnica favorável    65.384615
# Deferido                                                 26.923077
# Arquivado a pedido                                        5.769231
# Arquivado por decurso de prazo                            1.923077
# Name: status, dtype: float64

# %% [markdown]
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).

# %%
anos = []


for i in range(0, len(dados_rj.data_status)):
    anos.append(dados_rj.data_status.str.split(pat = '/')[i][2])
    
dados_rj['anos_status'] = anos
dados_rj
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       21660           Estado  Rio de Janeiro        33  RJ
# 1        5923           Estado  Rio de Janeiro        33  RJ
# 2       13629           Estado  Rio de Janeiro        33  RJ
# 3        5630           Estado  Rio de Janeiro        33  RJ
# 4        5635           Estado  Rio de Janeiro        33  RJ
# 5        5640           Estado  Rio de Janeiro        33  RJ
# 6       10562           Estado  Rio de Janeiro        33  RJ
# 7       13560           Estado  Rio de Janeiro        33  RJ
# 8       12375           Estado  Rio de Janeiro        33  RJ
# 9       13364           Estado  Rio de Janeiro        33  RJ
# 10      13271           Estado  Rio de Janeiro        33  RJ
# 11      10561           Estado  Rio de Janeiro        33  RJ
# 12       7129           Estado  Rio de Janeiro        33  RJ
# 13       7141           Estado  Rio de Janeiro        33  RJ
# ...

# %% [markdown]
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
dados_rj['anos_status'].value_counts(normalize = True)*100
# Out:
# 2012    21.153846
# 2009    17.307692
# 2013    13.461538
# 2011    11.538462
# 2016     7.692308
# 2002     7.692308
# 2014     7.692308
# 2010     5.769231
# 2006     3.846154
# 2008     3.846154
# Name: anos_status, dtype: float64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.

# %%
def ler_url(estado: str, interessado: str):
    url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=' + str(estado) + '&tipo_interessado=' + str(interessado)
    r = requests.get(url)
    df = pd.DataFrame(r.json()['items'])
    return df

# %%
df = ler_url('RJ', 'Estado')
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      21660           Estado  Rio de Janeiro        33  RJ
# 1       5923           Estado  Rio de Janeiro        33  RJ
# 2      13629           Estado  Rio de Janeiro        33  RJ
# 3       5630           Estado  Rio de Janeiro        33  RJ
# 4       5635           Estado  Rio de Janeiro        33  RJ
#
#                 num_pvl                                             status  \
# 0  00000.000000/2026-68                                 Arquivado a pedido
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None                                           Deferido
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.000245/2016-55  2016-03-11T03:00:00Z
# 1  17944.000234/2012-41  2012-04-16T03:00:00Z
# ...

# %% [markdown]
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?

# %%
df_mg = ler_url('MG', 'Estado')
df_mg.head(2)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      13641           Estado  Minas Gerais        31  MG    None
# 1      11054           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0                                           Deferido  19405.000042/2004-58
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001346/2012-10
#
#          data_protocolo                                      tipo_operacao  \
# 0  2004-11-26T02:00:00Z                        Operação contratual interna
# 1  2012-10-29T02:00:00Z  Operação contratual interna (com garantia da U...
#
#        finalidade                      tipo_credor  \
# 0  Infraestrutura  Instituição Financeira Nacional
# 1      Proinveste  Instituição Financeira Nacional
#
#                                               credor moeda         valor  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...  Real  5.377000e+07
# ...

# %%
df_mg['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
df_mg[df_mg['status'] == 'Arquivado por decurso de prazo']
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 14      20534           Estado  Minas Gerais        31  MG
#
#                  num_pvl                          status  \
# 14  00000.000000/2017-69  Arquivado por decurso de prazo
#
#             num_processo        data_protocolo                tipo_operacao  \
# 14  17944.001113/2015-60  2017-07-26T03:00:00Z  Operação contratual interna
#
#    finalidade                      tipo_credor  \
# 14       PMAE  Instituição Financeira Nacional
#
#                                                credor moeda      valor  \
# 14  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#     pvl_assoc_divida  pvl_contradado_credor data_status
# 14                 0                      0  16/03/2018

# %% [markdown]
# 3. Qual é o município da Bahia com mais solicitações deferidas?

# %%
df_ba = ler_url('BA', 'Município')
df_ba.head(2)
# Out:
#    id_pleito tipo_interessado    interessado  cod_ibge  uf num_pvl     status  \
# 0      18379        Município       Salvador   2927408  BA    None   Deferido
# 1      18409        Município  Campo Formoso   2906006  BA    None  Arquivado
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  19407.000011/2002-15  2002-03-25T03:00:00Z  Operação contratual interna
# 1  19407.000017/2003-73  2003-04-29T03:00:00Z  Operação contratual interna
#
#        finalidade                      tipo_credor  \
# 0           PNAFM  Instituição Financeira Nacional
# 1  Infraestrutura  Instituição Financeira Nacional
#
#                                       credor moeda        valor  \
# 0                    Caixa Econômica Federal  Real  21722799.00
# 1  Agência de Fomento do Estado da Bahia S/A  Real   1165672.72
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  12/07/2002
# ...

# %%
df_ba[df_ba['status'] == 'Deferido']['interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  9
#                           ..
# Matina                     1
# Mutuípe                    1
# Cocos                      1
# Nilo Peçanha               1
# Cravolândia                1
# Name: interessado, Length: 176, dtype: int64

# %% [markdown]
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_ba = ler_url('BA', 'Estado')
df_ba.to_csv('dados_ba.csv', index=False)
df_ba.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl    status  \
# 0      18368           Estado       Bahia        29  BA    None  Deferido
# 1      18389           Estado       Bahia        29  BA    None  Deferido
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  19407.000008/2005-44  2005-06-30T03:00:00Z  Operação contratual interna
# 1  19407.000013/2002-12  2002-05-31T03:00:00Z  Operação contratual interna
#
#           finalidade                      tipo_credor  \
# 0  Segurança pública  Instituição Financeira Nacional
# 1     Infraestrutura  Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0                                Banco do Brasil S/A  Dólar dos EUA
# 1  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  53839498.74                 1                      0  26/07/2005
# ...
